# %%
import pandas as pd
import numpy as np

# %%
def clean_data(df):
    sqm_to_sqft = 10.7639

    clean_area= df.area.str.replace(',','').str.replace('sq. ft', '').astype(float) / sqm_to_sqft
    df['sqft_in_sqm'] = df.sqft / sqm_to_sqft
    best_parsed = df[['sqft_in_sqm','sqm']].mean(axis=1)

    df['link'] = df.link.str.replace('//','/')

    df['best_sqm'] = np.where(pd.isnull(clean_area), best_parsed, clean_area)

    #df = df.drop(columns=['area', 'Unnamed: 0'])

    df.to_csv('processed_data.csv')

    return (df.sort_values('best_sqm',ascending=False))

# %%
import os
import json

files = os.listdir('json_data')

list_data = []

for f in files:
    with open('json_data/'+f) as js:
        data = json.load(js)
        list_data.append(data)

df = pd.DataFrame(list_data)
df.head(10)
# Out:
#                                             address     price    beds  \
# 0   St Stephens Avenue, Shepherd's Bush, London W12  £550,000  2 beds
# 1       Fearon Street, North Greenwich, London SE10  £550,000  2 beds
# 2              Church Street, Stratford, London E15  £565,000  2 beds
# 3                 Brick Lane, Shoreditch, London E1  £625,000  2 beds
# 4         The Laurels, Donnington Road, London NW10  £600,000  2 beds
# 5                      High Road Leyton, London E10  £595,000  3 beds
# 6  Flat F, Mercier Court, Mercier Road, Putney SW15  £570,000  2 beds
# 7   Imperial Building, Royal Arsenal Riverside SE18  £645,000  2 beds
# 8         Ilminster Gardens, Battersea, London SW11  £625,000  2 beds
# 9           Leyland Court, Sumner Road, London SE15  £557,500  2 beds
#
#          area     sqm    sqft                            image  \
# 0        None   61.96   667.0  ./extracted_images/60184094.jpg
# 1  761 sq. ft   70.70   761.0  ./extracted_images/60345700.jpg
# 2        None     NaN     NaN  ./extracted_images/58311065.jpg
# 3  560 sq. ft   52.00   560.0  ./extracted_images/55606520.jpg
# 4        None   60.00     NaN  ./extracted_images/57722815.jpg
# 5        None  116.53  1254.0  ./extracted_images/59663757.jpg
# 6        None   64.47   694.0  ./extracted_images/60790977.jpg
# 7        None     NaN     NaN                             None
# 8        None   69.68   760.0  ./extracted_images/60234171.jpg
# 9        None   84.10   905.0  ./extracted_images/60578874.jpg
#
#                                                 link listing_no  \
# 0  https://www.zoopla.co.uk//for-sale/details/601...   60184094
# 1  https://www.zoopla.co.uk//for-sale/details/603...   60345700
# 2  https://www.zoopla.co.uk//new-homes/details/58...   58311065
# 3  https://www.zoopla.co.uk//for-sale/details/556...   55606520
# 4  https://www.zoopla.co.uk//for-sale/details/577...   57722815
# 5  https://www.zoopla.co.uk//for-sale/details/596...   59663757
# 6  https://www.zoopla.co.uk//for-sale/details/607...   60790977
# 7  https://www.zoopla.co.uk//new-homes/details/52...   52210550
# 8  https://www.zoopla.co.uk//for-sale/details/602...   60234171
# 9  https://www.zoopla.co.uk//for-sale/details/605...   60578874
#
#                                                 gmap
# 0  {'@type': 'GeoCoordinates', 'latitude': 51.502...
# 1  {'@type': 'GeoCoordinates', 'latitude': 51.487...
# 2  {'@type': 'GeoCoordinates', 'latitude': 51.535...
# 3  {'@type': 'GeoCoordinates', 'latitude': 51.523...
# 4  {'@type': 'GeoCoordinates', 'latitude': 51.541...
# 5  {'@type': 'GeoCoordinates', 'latitude': 51.557...
# 6  {'@type': 'GeoCoordinates', 'latitude': 51.458...
# 7  {'@type': 'GeoCoordinates', 'latitude': 51.494...
# 8  {'@type': 'GeoCoordinates', 'latitude': 51.463...
# 9  {'@type': 'GeoCoordinates', 'latitude': 51.480...

# %%
df['latitude'] = [ x['latitude'] for x in df['gmap']]
df['longitude'] = [ x['longitude'] for x in df['gmap']]

clean_data(df).head(10)
# Out:
# /var/folders/f3/q97z0bxx5bs1ljyyd2flmknh0000gn/T/ipykernel_25274/467026207.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   clean_area= df.area.str.replace(',','').str.replace('sq. ft', '').astype(float) / sqm_to_sqft
#                                                 address     price    beds  \
# 989                            Cobden Walk, London SE15       POA  2 beds
# 1602       Eagle Wharf, 35 Narrow Street, Limehouse E14  £575,000  2 beds
# 2594                        Helmsdale Road, London SW16  £550,000  3 beds
# 2714                      Gladiator Street, London SE23  £635,000  2 beds
# 2762  Thane Villas, Finsbury Park, Islington, London N7  £635,000  2 beds
# 344   Royal Langford Apartments, Greville Road, Lond...  £625,000  2 beds
# 2988                          Leighton Road, London NW5  £600,000  2 beds
# 2445           Green Lanes, Newington Green, London N16  £600,000  2 beds
# 626                St Faiths Road, Dulwich, London SE21  £595,000  3 beds
# 494                             Audley Road, London NW4  £625,000  3 beds
#
#                area     sqm    sqft                            image  \
# 989            None  8445.0     NaN  ./extracted_images/58538883.jpg
# 1602           None  7203.0     NaN  ./extracted_images/60595919.jpg
# 2594           None  8142.0  8142.0  ./extracted_images/60782285.jpg
# 2714           None  7439.0  7439.0  ./extracted_images/60579905.jpg
# 2762           None  7710.0  2021.0  ./extracted_images/59261536.jpg
# 344            None  7116.0  7116.0  ./extracted_images/59934313.jpg
# 2988           None  6118.0  6978.0  ./extracted_images/60420151.jpg
# 2445           None  6131.0   670.0  ./extracted_images/60619014.jpg
# 626            None  4106.7  4106.0  ./extracted_images/58872530.jpg
# 494   13,003 sq. ft   112.2  1208.0  ./extracted_images/60253796.jpg
#
#                                                    link listing_no  \
# 989   https:/www.zoopla.co.uk/new-homes/details/5853...   58538883
# 1602  https:/www.zoopla.co.uk/for-sale/details/60595...   60595919
# 2594  https:/www.zoopla.co.uk/for-sale/details/60782...   60782285
# 2714  https:/www.zoopla.co.uk/for-sale/details/60579...   60579905
# 2762  https:/www.zoopla.co.uk/for-sale/details/59261...   59261536
# 344   https:/www.zoopla.co.uk/for-sale/details/59934...   59934313
# 2988  https:/www.zoopla.co.uk/for-sale/details/60420...   60420151
# 2445  https:/www.zoopla.co.uk/for-sale/details/60619...   60619014
# 626   https:/www.zoopla.co.uk/for-sale/details/58872...   58872530
# 494   https:/www.zoopla.co.uk/for-sale/details/60253...   60253796
#
#                                                    gmap   latitude  longitude  \
# 989   {'@type': 'GeoCoordinates', 'latitude': 51.473...  51.473171  -0.057752
# 1602  {'@type': 'GeoCoordinates', 'latitude': 51.509...  51.509323  -0.035042
# 2594  {'@type': 'GeoCoordinates', 'latitude': 51.415...  51.415088  -0.137253
# 2714  {'@type': 'GeoCoordinates', 'latitude': 51.448...  51.448350  -0.039574
# 2762  {'@type': 'GeoCoordinates', 'latitude': 51.56,...  51.560000  -0.112966
# 344   {'@type': 'GeoCoordinates', 'latitude': 51.536...  51.536104  -0.190885
# 2988  {'@type': 'GeoCoordinates', 'latitude': 51.550...  51.550730  -0.137701
# 2445  {'@type': 'GeoCoordinates', 'latitude': 51.554...  51.554210  -0.089033
# 626   {'@type': 'GeoCoordinates', 'latitude': 51.441...  51.441757  -0.104495
# 494   {'@type': 'GeoCoordinates', 'latitude': 51.577...  51.577329  -0.232742
#
#       sqft_in_sqm     best_sqm     geometry
# 989           NaN  8445.000000  POINT EMPTY
# 1602          NaN  7203.000000  POINT EMPTY
# 2594   756.417284  4449.208642  POINT EMPTY
# 2714   691.106383  4065.053192  POINT EMPTY
# 2762   187.757226  3948.878613  POINT EMPTY
# 344    661.098672  3888.549336  POINT EMPTY
# 2988   648.278040  3383.139020  POINT EMPTY
# 2445    62.245097  3096.622549  POINT EMPTY
# 626    381.460251  2244.080126  POINT EMPTY
# 494    112.226981  1208.019398  POINT EMPTY

# %%
import geopandas

# drop nan long and lat
gdf = geopandas.GeoDataFrame(df, geometry= geopandas.points_from_xy(df.longitude, df.latitude))

# %%
gdf
# Out:
#                                                 address     price    beds  \
# 0       St Stephens Avenue, Shepherd's Bush, London W12  £550,000  2 beds
# 1           Fearon Street, North Greenwich, London SE10  £550,000  2 beds
# 2                  Church Street, Stratford, London E15  £565,000  2 beds
# 3                     Brick Lane, Shoreditch, London E1  £625,000  2 beds
# 4             The Laurels, Donnington Road, London NW10  £600,000  2 beds
# ...                                                 ...       ...     ...
# 3027                          Spectrum Way, London SW18  £550,000  2 beds
# 3028         Sidmouth Street, King's Cross, London WC1H  £650,000  3 beds
# 3029  "Buttercup House" at Glenburnie Road, London SW17  £595,000  2 beds
# 3030     York Gate Apartments, 2 York Road, London SW11  £550,000  2 beds
# 3031               Wellington Quarte, Weston Point SE18  £595,000  3 beds
#
#             area    sqm   sqft                            image  \
# 0           None  61.96  667.0  ./extracted_images/60184094.jpg
# 1     761 sq. ft  70.70  761.0  ./extracted_images/60345700.jpg
# 2           None    NaN    NaN  ./extracted_images/58311065.jpg
# 3     560 sq. ft  52.00  560.0  ./extracted_images/55606520.jpg
# 4           None  60.00    NaN  ./extracted_images/57722815.jpg
# ...          ...    ...    ...                              ...
# 3027        None  62.69  675.0  ./extracted_images/60744584.jpg
# 3028  857 sq. ft  79.60  857.0  ./extracted_images/57552622.jpg
# 3029        None    NaN    NaN  ./extracted_images/60176456.jpg
# 3030        None  69.10  744.0  ./extracted_images/59762876.jpg
# 3031        None    NaN    NaN  ./extracted_images/60820141.jpg
#
#                                                    link listing_no  \
# 0     https:/www.zoopla.co.uk/for-sale/details/60184...   60184094
# 1     https:/www.zoopla.co.uk/for-sale/details/60345...   60345700
# 2     https:/www.zoopla.co.uk/new-homes/details/5831...   58311065
# 3     https:/www.zoopla.co.uk/for-sale/details/55606...   55606520
# 4     https:/www.zoopla.co.uk/for-sale/details/57722...   57722815
# ...                                                 ...        ...
# 3027  https:/www.zoopla.co.uk/new-homes/details/6074...   60744584
# 3028  https:/www.zoopla.co.uk/for-sale/details/57552...   57552622
# 3029  https:/www.zoopla.co.uk/new-homes/details/6017...   60176456
# 3030  https:/www.zoopla.co.uk/for-sale/details/59762...   59762876
# 3031  https:/www.zoopla.co.uk/for-sale/details/60820...   60820141
#
#                                                    gmap   latitude  longitude  \
# 0     {'@type': 'GeoCoordinates', 'latitude': 51.502...  51.502897  -0.231709
# 1     {'@type': 'GeoCoordinates', 'latitude': 51.487...  51.487075   0.017821
# 2     {'@type': 'GeoCoordinates', 'latitude': 51.535...  51.535872   0.010823
# 3     {'@type': 'GeoCoordinates', 'latitude': 51.523...  51.523725  -0.071887
# 4     {'@type': 'GeoCoordinates', 'latitude': 51.541...  51.541230  -0.232630
# ...                                                 ...        ...        ...
# 3027  {'@type': 'GeoCoordinates', 'latitude': 51.456...  51.456177  -0.197214
# 3028  {'@type': 'GeoCoordinates', 'latitude': 51.527...  51.527491  -0.119471
# 3029  {'@type': 'GeoCoordinates', 'latitude': 51.437...  51.437358  -0.172373
# 3030  {'@type': 'GeoCoordinates', 'latitude': 51.470...  51.470166  -0.173068
# 3031  {'@type': 'GeoCoordinates', 'latitude': 51.488...  51.488651   0.063716
#
#       sqft_in_sqm   best_sqm                   geometry
# 0       61.966388  61.963194  POINT (-0.23171 51.50290)
# 1       70.699282  70.699282   POINT (0.01782 51.48707)
# 2             NaN        NaN   POINT (0.01082 51.53587)
# 3       52.025753  52.025753  POINT (-0.07189 51.52372)
# 4             NaN  60.000000  POINT (-0.23263 51.54123)
# ...           ...        ...                        ...
# 3027    62.709613  62.699806  POINT (-0.19721 51.45618)
# 3028    79.617982  79.617982  POINT (-0.11947 51.52749)
# 3029          NaN        NaN  POINT (-0.17237 51.43736)
# 3030    69.119929  69.109964  POINT (-0.17307 51.47017)
# 3031          NaN        NaN   POINT (0.06372 51.48865)
#
# [3032 rows x 15 columns]

# %%
gdf.set_crs(crs='EPSG:4326', inplace=True)
gdf[(df.best_sqm > 72) & (df.best_sqm < 150 ) & (df.price > "£500,000")].explore("best_sqm", tiles = "CartoDB dark_matter", popup = True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c3d44f2bbcbe43fd9d6ddaf6a99e306b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20table%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20margin%3A%20auto%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...
